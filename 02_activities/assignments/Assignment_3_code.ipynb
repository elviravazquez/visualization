# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# /Users/elvira/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# upload the data
data = pd.read_csv('dataset.csv')

# %%
data
# Out:
#            _id  Year  FSA ANIMAL_TYPE  PRIMARY_BREED
# 0            1  2023  M1C         DOG    GOLDEN RETR
# 1            2  2024  M9P         DOG       SHIH TZU
# 2            3  2025  M3A         DOG  LABRADOR RETR
# 3            4  2025  M4A         DOG  BORDER COLLIE
# 4            5  2024  M3B         CAT    DOMESTIC LH
# ...        ...   ...  ...         ...            ...
# 224410  224411  2025  NaN         DOG    COCKER SPAN
# 224411  224412  2026  M6C         DOG     CANE CORSO
# 224412  224413  2026  M4K         DOG  BORDER COLLIE
# 224413  224414  2026  M1G         CAT    DOMESTIC SH
# 224414  224415  2026  M6N         DOG  LABRADOR RETR
#
# [224415 rows x 5 columns]

# %%
data['ANIMAL_TYPE']
# Out:
# 0         DOG
# 1         DOG
# 2         DOG
# 3         DOG
# 4         CAT
#          ...
# 224410    DOG
# 224411    DOG
# 224412    DOG
# 224413    CAT
# 224414    DOG
# Name: ANIMAL_TYPE, Length: 224415, dtype: object

# %%
df[df['A'] > 0]
